# %% [markdown]
# <a href="https://colab.research.google.com/github/busragmsy/IoBDataAnalysis/blob/data-wrangling/data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import requests
import pandas as pd
from datetime import datetime

# Fonksiyon: Belirli tarih aralığı için veri çek
def fetch_weather_data(start_date, end_date, latitude=41.03, longitude=28.84):
    url = f"https://archive-api.open-meteo.com/v1/archive?latitude={latitude}&longitude={longitude}&start_date={start_date}&end_date={end_date}&daily=temperature_2m_max,temperature_2m_min,temperature_2m_mean,precipitation_sum,relative_humidity_2m_mean,windspeed_10m_max,winddirection_10m_dominant,cloudcover_mean&timezone=Europe%2FIstanbul"
    response = requests.get(url)
    if response.status_code == 200:
        data = response.json()['daily']
        df = pd.DataFrame(data)
        df['datetime'] = pd.to_datetime(df['time'])  # Tarih sütunu ekle
        return df
    else:
        print(f"Hata: {response.status_code}")
        return None

# Yıl yıl çek ve birleştir (2012-2025)
years = range(2012, 2026)  # 2025 dahil
all_data = []

for year in years:
    start = f"{year}-01-01"
    end = f"{year}-12-31"
    df_year = fetch_weather_data(start, end)
    if df_year is not None:
        all_data.append(df_year)
    print(f"{year} yılı çekildi.")

# Tüm veriyi birleştir ve CSV'ye kaydet
if all_data:
    df_full = pd.concat(all_data, ignore_index=True)
    df_full.to_csv('istanbul_bagcilar_2012_2025_hava.csv', index=False)
    print("Tam veri 'istanbul_bagcilar_2012_2025_hava.csv' olarak kaydedildi.")
else:
    print("Veri çekilemedi.")
# Out:
# 2012 yılı çekildi.
# 2013 yılı çekildi.
# 2014 yılı çekildi.
# 2015 yılı çekildi.
# 2016 yılı çekildi.
# 2017 yılı çekildi.
# 2018 yılı çekildi.
# 2019 yılı çekildi.
# 2020 yılı çekildi.
# 2021 yılı çekildi.
# 2022 yılı çekildi.
# 2023 yılı çekildi.
# 2024 yılı çekildi.
# 2025 yılı çekildi.
# Tam veri 'istanbul_bagcilar_2012_2025_hava.csv' olarak kaydedildi.

# %%
import requests
import pandas as pd

# Tam lokanta koordinatları
latitude = 41.04307772749923
longitude = 28.813459723655757

def fetch_hourly_weather(start_date, end_date):
    url = f"https://archive-api.open-meteo.com/v1/archive?latitude={latitude}&longitude={longitude}&start_date={start_date}&end_date={end_date}&hourly=temperature_2m,relative_humidity_2m,precipitation,rain,showers,snowfall,windspeed_10m,winddirection_10m,cloudcover,visibility&timezone=Europe%2FIstanbul"
    response = requests.get(url)
    if response.status_code == 200:
        data = response.json()['hourly']
        df = pd.DataFrame(data)
        df['datetime'] = pd.to_datetime(df['time'])  # Saatlik datetime sütunu
        return df
    else:
        print(f"Hata: {response.status_code} - {response.text}")
        return None

# Yıl yıl çek (2012-2025)
years = range(2012, 2026)
all_data = []

for year in years:
    start = f"{year}-01-01"
    end = f"{year}-12-31"
    df_year = fetch_hourly_weather(start, end)
    if df_year is not None:
        all_data.append(df_year)
    print(f"{year} yılı saatlik veri çekildi.")

# Tüm veriyi birleştir ve CSV'ye kaydet
if all_data:
    df_full = pd.concat(all_data, ignore_index=True)
    df_full.to_csv('istanbul_bagcilar_tam_koordinat_2012_2025_saatlik_hava.csv', index=False)
    print("Saatlik CSV kaydedildi: istanbul_bagcilar_tam_koordinat_2012_2025_saatlik_hava.csv")
    print(f"Toplam satır sayısı: {len(df_full)} (yaklaşık 5.114 gün x 24 = ~122.736 kayıt)")
else:
    print("Veri çekilemedi.")
# Out:
# 2012 yılı saatlik veri çekildi.
# 2013 yılı saatlik veri çekildi.
# 2014 yılı saatlik veri çekildi.
# 2015 yılı saatlik veri çekildi.
# 2016 yılı saatlik veri çekildi.
# 2017 yılı saatlik veri çekildi.
# 2018 yılı saatlik veri çekildi.
# 2019 yılı saatlik veri çekildi.
# 2020 yılı saatlik veri çekildi.
# 2021 yılı saatlik veri çekildi.
# 2022 yılı saatlik veri çekildi.
# 2023 yılı saatlik veri çekildi.
# 2024 yılı saatlik veri çekildi.
# 2025 yılı saatlik veri çekildi.
# Saatlik CSV kaydedildi: istanbul_bagcilar_tam_koordinat_2012_2025_saatlik_hava.csv
# Toplam satır sayısı: 122736 (yaklaşık 5.114 gün x 24 = ~122.736 kayıt)

# %%
import requests
import pandas as pd

latitude = 41.04307772749923
longitude = 28.813459723655757

def fetch_hourly_weather(start_date, end_date):
    url = f"https://archive-api.open-meteo.com/v1/archive?latitude={latitude}&longitude={longitude}&start_date={start_date}&end_date={end_date}&hourly=temperature_2m,apparent_temperature,relative_humidity_2m,dewpoint_2m,precipitation,rain,showers,snowfall,windspeed_10m,winddirection_10m,cloudcover,visibility,uv_index,is_day,shortwave_radiation,pressure_msl&timezone=Europe%2FIstanbul"
    response = requests.get(url)
    if response.status_code == 200:
        data = response.json()['hourly']
        df = pd.DataFrame(data)
        df['datetime'] = pd.to_datetime(df['time'])
        return df
    else:
        print(f"Hata: {response.status_code} - {response.text}")
        return None

# Yıl yıl çek (2012-2025)
years = range(2012, 2026)
all_data = []

for year in years:
    start = f"{year}-01-01"
    end = f"{year}-12-31"
    df_year = fetch_hourly_weather(start, end)
    if df_year is not None:
        all_data.append(df_year)
    print(f"{year} yılı saatlik veri çekildi.")

if all_data:
    df_full = pd.concat(all_data, ignore_index=True)
    df_full.to_csv('istanbul_bagcilar_tam_koordinat_2012_2025_saatlik_hava_genis.csv', index=False)
    print("Genişletilmiş saatlik CSV kaydedildi!")
# Out:
# 2012 yılı saatlik veri çekildi.
# 2013 yılı saatlik veri çekildi.
# 2014 yılı saatlik veri çekildi.
# 2015 yılı saatlik veri çekildi.
# 2016 yılı saatlik veri çekildi.
# 2017 yılı saatlik veri çekildi.
# 2018 yılı saatlik veri çekildi.
# 2019 yılı saatlik veri çekildi.
# 2020 yılı saatlik veri çekildi.
# 2021 yılı saatlik veri çekildi.
# 2022 yılı saatlik veri çekildi.
# 2023 yılı saatlik veri çekildi.
# 2024 yılı saatlik veri çekildi.
# 2025 yılı saatlik veri çekildi.
# Genişletilmiş saatlik CSV kaydedildi!

# %%
import pandas as pd

file_path = '/content/drive/MyDrive/Colab Notebooks/TubitakIoB/TubitakVeriler.csv'
df_tubitak = pd.read_csv(file_path)
display(df_tubitak.head())
# Out:
#      02  2012-07-21 00:00:00.000  20:10  21:50 2012-07-21 00:00:00.000.1  \
# 0    02  2012-07-21 00:00:00.000  20:10  21:50   2012-07-21 00:00:00.000
# 1   P01  2012-07-23 00:00:00.000  11:32  11:46   2012-07-23 00:00:00.000
# 2   P01  2012-07-23 00:00:00.000  11:32  11:46   2012-07-23 00:00:00.000
# 3   P01  2012-07-23 00:00:00.000  11:32  11:46   2012-07-23 00:00:00.000
# 4   P01  2012-07-23 00:00:00.000  11:32  11:46   2012-07-23 00:00:00.000
# 5   P01  2012-07-23 00:00:00.000  11:32  11:46   2012-07-23 00:00:00.000
# 6   P01  2012-07-23 00:00:00.000  11:32  11:46   2012-07-23 00:00:00.000
# 7   P01  2012-07-23 00:00:00.000  11:32  11:46   2012-07-23 00:00:00.000
# 8   P01  2012-07-23 00:00:00.000  11:32  11:46   2012-07-23 00:00:00.000
# 9   P01  2012-07-23 00:00:00.000  11:32  11:46   2012-07-23 00:00:00.000
# 10  P01  2012-07-23 00:00:00.000  11:32  11:46   2012-07-23 00:00:00.000
# 11  P01  2012-07-23 00:00:00.000  11:32  11:46   2012-07-23 00:00:00.000
# 12  P01  2012-07-23 00:00:00.000  11:32  11:46   2012-07-23 00:00:00.000
# 13  P01  2012-07-23 00:00:00.000  11:32  11:46   2012-07-23 00:00:00.000
# 14  P01  2012-07-23 00:00:00.000  11:32  11:46   2012-07-23 00:00:00.000
# 15  P01  2012-07-23 00:00:00.000  11:32  11:46   2012-07-23 00:00:00.000
# 16  P01  2012-07-23 00:00:00.000  11:32  11:46   2012-07-23 00:00:00.000
# 17  P01  2012-07-23 00:00:00.000  11:32  11:46   2012-07-23 00:00:00.000
# 18  P01  2012-07-23 00:00:00.000  11:32  11:46   2012-07-23 00:00:00.000
# 19  P01  2012-07-23 00:00:00.000  11:32  11:46   2012-07-23 00:00:00.000
# 20  P01  2012-07-23 00:00:00.000  11:32  11:46   2012-07-23 00:00:00.000
# 21  P01  2012-07-23 00:00:00.000  11:32  11:46   2012-07-23 00:00:00.000
# 22  P04  2012-07-23 00:00:00.000  11:35  11:46   2012-07-23 00:00:00.000
# 23  P04  2012-07-23 00:00:00.000  11:35  11:46   2012-07-23 00:00:00.000
# 24  P04  2012-07-23 00:00:00.000  11:35  11:46   2012-07-23 00:00:00.000
# 25  P02  2012-07-23 00:00:00.000  12:03  12:24   2012-07-23 00:00:00.000
# 26  P02  2012-07-23 00:00:00.000  12:03  12:24   2012-07-23 00:00:00.000
# 27  P02  2012-07-23 00:00:00.000  12:03  12:24   2012-07-23 00:00:00.000
# 28  P01  2012-07-23 00:00:00.000  11:56  12:24   2012-07-23 00:00:00.000
# 29  P01  2012-07-23 00:00:00.000  11:56  12:24   2012-07-23 00:00:00.000
# 30  P01  2012-07-23 00:00:00.000  11:56  12:24   2012-07-23 00:00:00.000
# 31  B01  2012-07-23 00:00:00.000  12:00  12:25   2012-07-23 00:00:00.000
# 32  B01  2012-07-23 00:00:00.000  12:00  12:25   2012-07-23 00:00:00.000
# 33  B01  2012-07-23 00:00:00.000  12:00  12:25   2012-07-23 00:00:00.000
# 34  S05  2012-07-23 00:00:00.000  12:19  12:38   2012-07-23 00:00:00.000
# 35  S05  2012-07-23 00:00:00.000  12:19  12:38   2012-07-23 00:00:00.000
# 36  S05  2012-07-23 00:00:00.000  12:19  12:38   2012-07-23 00:00:00.000
# 37  S01  2012-07-23 00:00:00.000  11:39  12:39   2012-07-23 00:00:00.000
# 38  S01  2012-07-23 00:00:00.000  11:39  12:39   2012-07-23 00:00:00.000
# 39  S01  2012-07-23 00:00:00.000  11:39  12:39   2012-07-23 00:00:00.000
# 40  S01  2012-07-23 00:00:00.000  11:39  12:39   2012-07-23 00:00:00.000
# 41  S01  2012-07-23 00:00:00.000  11:39  12:39   2012-07-23 00:00:00.000
# 42  S04  2012-07-23 00:00:00.000  12:14  12:39   2012-07-23 00:00:00.000
# 43  S04  2012-07-23 00:00:00.000  12:14  12:39   2012-07-23 00:00:00.000
# 44  S02  2012-07-23 00:00:00.000  12:14  12:39   2012-07-23 00:00:00.000
# 45  S02  2012-07-23 00:00:00.000  12:14  12:39   2012-07-23 00:00:00.000
# 46  P01  2012-07-23 00:00:00.000  12:28  12:51   2012-07-23 00:00:00.000
# 47  P01  2012-07-23 00:00:00.000  12:28  12:51   2012-07-23 00:00:00.000
# 48  P01  2012-07-23 00:00:00.000  12:28  12:51   2012-07-23 00:00:00.000
# 49  P01  2012-07-23 00:00:00.000  13:05  13:11   2012-07-23 00:00:00.000
#
#                            FULL  1.00  7.00
# 0                           NaN   NaN   NaN
# 1                       ICE TEA   1.0   2.5
# 2                       ICE TEA   1.0   2.5
# 3                       ICE TEA   1.0   2.5
# 4                          SODA   1.0   1.0
# 5                          SODA   1.0   1.0
# 6                          SODA   1.0   1.0
# 7                          SODA   1.0   1.0
# 8                      COCACOLA   1.0   2.5
# 9                   ACISIZ FULL   1.0   7.0
# 10                     PORSIYON   1.0  20.0
# 11         ACISIZ SADE MAYDONOZ   1.0   7.0
# 12          AZ ACILI YARIM FULL   1.0   7.0
# 13                         FULL   1.0   7.0
# 14                       SALGAM   1.0   2.5
# 15            ACISIZ DOMATESSİZ   1.0   7.0
# 16                         FULL   1.0   7.0
# 17                         FULL   1.0   7.0
# 18                         FULL   1.0   7.0
# 19                        AYRAN   1.0   2.5
# 20                       KUNUFE   1.0   7.0
# 21                          NaN   NaN   NaN
# 22  ACISIZ 3 CEYREK MAYDONOZSUZ   1.0  11.0
# 23         ACISIZ 3 CEYREK SADE   1.0  11.0
# 24                          NaN   NaN   NaN
# 25                   DOMATESSİZ   1.0   7.0
# 26                         FULL   1.0   7.0
# 27                          NaN   NaN   NaN
# 28            ACISIZ YARIM FULL   1.0   7.0
# 29                        AYRAN   1.0   2.5
# 30                          NaN   NaN   NaN
# 31                         FULL   1.0   7.0
# 32             YARIM DOMATESSIZ   1.0   7.0
# 33                          NaN   NaN   NaN
# 34                     COCACOLA   1.5   2.5
# 35                     COCACOLA   1.5   2.5
# 36                          NaN   NaN   NaN
# 37                  MAYDANOZSUZ   1.0   7.0
# 38                         FULL   1.0   7.0
# 39                        AYRAN   1.0   2.5
# 40                        AYRAN   1.0   2.5
# 41                          NaN   NaN   NaN
# 42                  ACISIZ FULL   1.5   7.0
# 43                          NaN   NaN   NaN
# 44                   DOMATESSİZ   1.5   7.0
# 45                          NaN   NaN   NaN
# 46              ACISIZ SOGANSIZ   1.0   7.0
# 47                        AYRAN   1.0   2.5
# 48                          NaN   NaN   NaN
# 49      ACISIZ YARIM SADE SOGAN   1.0   7.0

# %%
import pandas as pd

# Dosya yolunu kendi yolunla değiştir (Colab'da sağ tıklayıp "Copy path" yapabilirsin)
file_path = '/content/drive/MyDrive/Colab Notebooks/TubitakIoB/TubitakVeriler.csv'

# Başlıksız oku
df = pd.read_csv(file_path, header=None)

# Sütun isimlerini ata (SQL sorguna göre tam eşleşme)
df.columns = [
    'MASANO',
    'ACILIS_TARIHI',
    'ACILIS_SAATI',
    'KAPAMA_SAATI',
    'TARIH',
    'STOKADI',
    'MIKTAR',
    'SATIS_FIYATI'
]

# İlk 5 satırı göster (kontrol için)
print("Başlık eklendikten sonra ilk 5 satır:")
display(df.head())

# Yeni başlıklı dosyayı kaydet
output_path = '/content/drive/MyDrive/Colab Notebooks/TubitakIoB/TubitakCustomerData.csv'
df.to_csv(output_path, index=False, encoding='utf-8-sig')

print(f"\nBaşlıklı dosya başarıyla kaydedildi: {output_path}")
# Out:
# Başlık eklendikten sonra ilk 5 satır:
#   MASANO            ACILIS_TARIHI ACILIS_SAATI KAPAMA_SAATI  \
# 0     02  2012-07-21 00:00:00.000        20:10        21:50
# 1     02  2012-07-21 00:00:00.000        20:10        21:50
# 2    P01  2012-07-23 00:00:00.000        11:32        11:46
# 3    P01  2012-07-23 00:00:00.000        11:32        11:46
# 4    P01  2012-07-23 00:00:00.000        11:32        11:46
#
#                      TARIH  STOKADI  MIKTAR  SATIS_FIYATI
# 0  2012-07-21 00:00:00.000     FULL     1.0           7.0
# 1  2012-07-21 00:00:00.000      NaN     NaN           NaN
# 2  2012-07-23 00:00:00.000  ICE TEA     1.0           2.5
# 3  2012-07-23 00:00:00.000  ICE TEA     1.0           2.5
# 4  2012-07-23 00:00:00.000  ICE TEA     1.0           2.5
# Başlıklı dosya başarıyla kaydedildi: /content/drive/MyDrive/Colab Notebooks/TubitakIoB/TubitakCustomerData.csv

# %%
import pandas as pd

file_path = '/content/drive/MyDrive/Colab Notebooks/TubitakIoB/CustomerData.csv'

# 1. CSV dosyasını yükle
df = pd.read_csv(file_path)

# 2. Tarih-saat sütunlarını datetime formatına çevir
df['acilis_datetime'] = pd.to_datetime(
    df['ACILIS_TARIHI'].astype(str) + ' ' + df['ACILIS_SAATI'].astype(str),
    errors='coerce'
)

df['kapama_datetime'] = pd.to_datetime(
    df['ACILIS_TARIHI'].astype(str) + ' ' + df['KAPAMA_SAATI'].astype(str),
    errors='coerce'
)

# Oturum süresi hesapla (dakika cinsinden)
df['oturum_sure_dk'] = (df['kapama_datetime'] - df['acilis_datetime']).dt.total_seconds() / 60

# 3. Gruplama: MASANO + CEKNO bazında özetle
df_grup = df.groupby(['MASANO', 'CEKNO', 'acilis_datetime', 'kapama_datetime', 'oturum_sure_dk']).agg(
    toplam_miktar=('MIKTAR', 'sum'),           # Tüm ürünlerin toplam miktarı
    toplam_tutar=('SATIS_FIYATI', 'sum'),      # Oturumun toplam satış tutarı
    urun_listesi=('STOKADI', lambda x: list(x.unique())),  # Oturumdaki benzersiz ürün isimleri (liste)
    ilk_siparis_zamani=('TARIH', 'min')        # Oturumdaki ilk sipariş zamanı (opsiyonel)
).reset_index()

# 4. Hava verisiyle birleştirmek için yuvarlanmış saat ekle
# (Açılış saatini saat başı yuvarla – hava verisi saatlik olduğu için)
df_grup['merge_saati'] = df_grup['acilis_datetime'].dt.floor('H')

# 5. Sonucu yeni bir CSV olarak kaydet
output_path = '/content/drive/MyDrive/Colab Notebooks/TubitakIoB/grup_oturum_bazli_tubitak.csv'
df_grup.to_csv(output_path, index=False, encoding='utf-8-sig')

print("Gruplama tamamlandı!")
print("Yeni dosya: grup_oturum_bazli_tubitak.csv")
print("\nİlk 5 satır örnek:")
print(df_grup.head())
# Out:
# /tmp/ipython-input-1327341052.py:9: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['acilis_datetime'] = pd.to_datetime(
# /tmp/ipython-input-1327341052.py:14: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['kapama_datetime'] = pd.to_datetime(
# /tmp/ipython-input-1327341052.py:32: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   df_grup['merge_saati'] = df_grup['acilis_datetime'].dt.floor('H')
# Gruplama tamamlandı!
# Yeni dosya: grup_oturum_bazli_tubitak.csv
#
# İlk 5 satır örnek:
#   MASANO  CEKNO     acilis_datetime     kapama_datetime  oturum_sure_dk  \
# 0     02      3 2012-07-21 20:10:00 2012-07-21 21:50:00           100.0
# 1    333  69661 2015-04-13 18:01:00 2015-04-13 18:01:00             0.0
# 2    B01     21 2012-07-23 12:00:00 2012-07-23 12:25:00            25.0
# 3    B01     41 2012-07-23 18:32:00 2012-07-23 18:36:00             4.0
# 4    B01     67 2012-07-24 17:04:00 2012-07-24 17:20:00            16.0
#
#    toplam_miktar  toplam_tutar                 urun_listesi  \
# 0            1.0           7.0                       [FULL]
# 1            1.0         109.0                         [SU]
# 2            2.0          14.0     [FULL, YARIM DOMATESSIZ]
# 3            2.0           9.5     [ACISIZ SOGANSIZ, AYRAN]
# 4            4.0          19.0  [AZ ACILI SOGANSIZ, SALGAM]
#
#         ilk_siparis_zamani         merge_saati
# 0  2012-07-21 00:00:00.000 2012-07-21 20:00:00
# 1  2015-04-13 00:00:00.000 2015-04-13 18:00:00
# 2  2012-07-23 00:00:00.000 2012-07-23 12:00:00
# 3  2012-07-23 00:00:00.000 2012-07-23 18:00:00
# 4  2012-07-24 00:00:00.000 2012-07-24 17:00:00
